# %% [markdown]
# ####Clone github PaddleOCR

# %%
# %%shell
# git clone https://github.com/PaddlePaddle/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 47374, done.
# remote: Counting objects: 100% (618/618), done.
# remote: Compressing objects: 100% (353/353), done.
# remote: Total 47374 (delta 390), reused 443 (delta 262), pack-reused 46756
# Receiving objects: 100% (47374/47374), 345.20 MiB | 33.36 MiB/s, done.
# Resolving deltas: 100% (33240/33240), done.
# Updating files: 100% (1891/1891), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ####Upload and unzip dataset

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/train/
# !unzip /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/train/10102023-det.zip
# !unzip /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/train/recognition_train.zip

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test
# !unzip /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2.zip
# !unzip /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data-20231009T152741Z-001.zip
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test
# Archive:  /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2.zip
#    creating: data2/images/
#   inflating: data2/images/20230420_000001.jpg
#   inflating: data2/images/20230420_000002.jpg
#   inflating: data2/images/20230420_000003.jpg
#   inflating: data2/images/20230420_000004.jpg
#   inflating: data2/images/20230420_000005.jpg
#   inflating: data2/images/20230420_000006.jpg
#   inflating: data2/images/20230420_000007.jpg
#   inflating: data2/images/20230420_000008.jpg
#   inflating: data2/images/20230420_000009.jpg
#  extracting: data2/images/20230420_000010.jpg
#   inflating: data2/images/20230420_000011.jpg
#   inflating: data2/images/20230420_000012.jpg
#   inflating: data2/images/20230420_000013.jpg
#   inflating: data2/images/20230420_000014.jpg
#   inflating: data2/images/20230420_000015.jpg
#   inflating: data2/images/20230420_000016.jpg
#   inflating: data2/images/20230420_000017.jpg
# ...

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/PaddleOCR/train_data
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_det_distill_train.tar
# !tar xf ch_PP-OCRv3_det_distill_train.tar
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/PaddleOCR/train_data'
# /content
# --2023-10-09 15:48:41--  https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_det_distill_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 124.237.208.76, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|124.237.208.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139341312 (133M) [application/x-tar]
# Saving to: ‘ch_PP-OCRv3_det_distill_train.tar’
#
# ch_PP-OCRv3_det_dis 100%[===================>] 132.89M  16.7MB/s    in 23s
#
# 2023-10-09 15:49:06 (5.70 MB/s) - ‘ch_PP-OCRv3_det_distill_train.tar’ saved [139341312/139341312]

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model
# !tar xf ch_PP-OCRv3_det_distill_train.tar
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model

# %% [markdown]
# ####Install necessary package

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR

# %%
# !pip install paddlepaddle-gpu pyclipper attrdict -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.0/541.0 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 66.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 40.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00

# %%
# !pip install -e
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
# !pip install wandb -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 22.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import wandb

# %%
wandb.login()
#c0393d3b024743cef0d5cd9ec217e3359fad0e3a
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !wget http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb

# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# Out:
# --2023-10-12 09:33:11--  http://nz2.archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb
# Resolving nz2.archive.ubuntu.com (nz2.archive.ubuntu.com)... 185.125.190.36, 91.189.91.83, 91.189.91.81, ...
# Connecting to nz2.archive.ubuntu.com (nz2.archive.ubuntu.com)|185.125.190.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1321244 (1.3M) [application/x-debian-package]
# Saving to: ‘libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb.6’
#
# libssl1.1_1.1.1f-1u 100%[===================>]   1.26M  1.94MB/s    in 0.6s
#
# 2023-10-12 09:33:12 (1.94 MB/s) - ‘libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb.6’ saved [1321244/1321244]
#
# Selecting previously unselected package libssl1.1:amd64.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack libssl1.1_1.1.1f-1ubuntu2.19_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1f-1ubuntu2.19) ...
# Setting up libssl1.1:amd64 (1.1.1f-1ubuntu2.19) ...
# ...

# %%
# !pip install lanms-nova
# !pip install lmdb
# !pip install rapidfuzz
# !pip install visualdl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.3/219.3 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lanms-nova: filename=lanms_nova-1.0.3-cp310-cp310-linux_x86_64.whl size=1268300 sha256=a91695fee03f4520f21b79bf27fb2c43d877d01c6b8dfe21f7edfc243748d36c
#   Stored in directory: /root/.cache/pip/wheels/61/ff/81/814bf77943755a77768709bba2eb39a0b5005d54dd22072e6d
# Successfully built lanms-nova
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.3/235.3 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Detection Model Training

# %% [markdown]
# ####Trích xuất các đặc trưng từ Student của model PPOCRV3

# %%
import paddle
# 加载预训练模型
all_params = paddle.load("/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/best_accuracy.pdparams")
# 查看权重参数的keys
print(all_params.keys())
# 模型的权重提取
s_params = {key[len("Student."):]: all_params[key] for key in all_params if "Student." in key}
# 查看模型权重参数的keys
print(s_params.keys())
# 保存
paddle.save(s_params, "/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/student_09102023.pdparams")
# Out:
# dict_keys(['Student2.backbone.conv.conv.weight', 'Student.backbone.conv.conv.weight', 'Student2.backbone.conv.bn.weight', 'Student.backbone.conv.bn.weight', 'Student2.backbone.conv.bn.bias', 'Student.backbone.conv.bn.bias', 'Student2.backbone.conv.bn._mean', 'Student.backbone.conv.bn._mean', 'Student2.backbone.conv.bn._variance', 'Student.backbone.conv.bn._variance', 'Student2.backbone.stage0.0.expand_conv.conv.weight', 'Student.backbone.stage0.0.expand_conv.conv.weight', 'Student2.backbone.stage0.0.expand_conv.bn.weight', 'Student.backbone.stage0.0.expand_conv.bn.weight', 'Student2.backbone.stage0.0.expand_conv.bn.bias', 'Student.backbone.stage0.0.expand_conv.bn.bias', 'Student2.backbone.stage0.0.expand_conv.bn._mean', 'Student.backbone.stage0.0.expand_conv.bn._mean', 'Student2.backbone.stage0.0.expand_conv.bn._variance', 'Student.backbone.stage0.0.expand_conv.bn._variance', 'Student2.backbone.stage0.0.bottleneck_conv.conv.weight', 'Student.backbone.stage0.0.bottleneck_conv.conv.wei
# ...

# %% [markdown]
# ####Trích xuất các đặc trưng từ Teacher của model PPOCRV3

# %%
import paddle
# 加载预训练模型
all_params = paddle.load("/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/best_accuracy.pdparams")
# 查看权重参数的keys
print(all_params.keys())
# 模型的权重提取
s_params = {key[len("Teacher."):]: all_params[key] for key in all_params if "Teacher." in key}
# 查看模型权重参数的keys
print(s_params.keys())
# 保存
paddle.save(s_params, "/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/teacher_10102023.pdparams")
# Out:
# dict_keys(['Student2.backbone.conv.conv.weight', 'Student.backbone.conv.conv.weight', 'Student2.backbone.conv.bn.weight', 'Student.backbone.conv.bn.weight', 'Student2.backbone.conv.bn.bias', 'Student.backbone.conv.bn.bias', 'Student2.backbone.conv.bn._mean', 'Student.backbone.conv.bn._mean', 'Student2.backbone.conv.bn._variance', 'Student.backbone.conv.bn._variance', 'Student2.backbone.stage0.0.expand_conv.conv.weight', 'Student.backbone.stage0.0.expand_conv.conv.weight', 'Student2.backbone.stage0.0.expand_conv.bn.weight', 'Student.backbone.stage0.0.expand_conv.bn.weight', 'Student2.backbone.stage0.0.expand_conv.bn.bias', 'Student.backbone.stage0.0.expand_conv.bn.bias', 'Student2.backbone.stage0.0.expand_conv.bn._mean', 'Student.backbone.stage0.0.expand_conv.bn._mean', 'Student2.backbone.stage0.0.expand_conv.bn._variance', 'Student.backbone.stage0.0.expand_conv.bn._variance', 'Student2.backbone.stage0.0.bottleneck_conv.conv.weight', 'Student.backbone.stage0.0.bottleneck_conv.conv.wei
# ...

# %% [markdown]
# ####Training model Student MobileNetV3 dựa trên Teacher của PPOCRV3

# %%
# 单卡训练
# !python3 tools/train.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PP-OCR3_det_student_1.yml \
    -o Global.pretrained_model=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/student_09102023.pdparams \
    Global.checkpoints=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/latest.pdparams
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/detection_PPOCR3student_1/wandb/run-20231010_021754-4lsbabpw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run whole-aardvark-5
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1/runs/4lsbabpw
# [2023/10/10 02:17:58] ppocr INFO: Architecture :
# [2023/10/10 02:17:58] ppocr INFO:     Backbone :
# [2023/10/10 02:17:58] ppocr INFO:         disable_se : True
# [2023/10/10 02:17:58] ppocr INFO:         model_name : large
# [2023/10/10 02:17:58] ppocr INFO:         name : MobileNetV3
# [2023/10/10 02:17:58] ppocr INFO:         scale : 0.5
# [2023/10/10 02:17:58] ppocr INFO:     Head :
# [2023/10/10 02:17:58] ppocr INFO:         k : 50
# ...

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PP-OCR3_det_cml.yml \
    -o Architecture.Models.Student.pretrained=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/best_accuracy_res50_12e.pdparams \
       Architecture.Models.Student2.pretrained=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/best_accuracy.pdparams \
       Architecture.Models.Teacher.pretrained=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/teacher_10102023.pdparams \
       Global.checkpoints=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/det_cml_10102023_ver1/latest.pdparams
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/det_cml_10102023_ver1/wandb/run-20231010_061804-dgmxuy8k
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run misty-silence-5
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/det_cml_train_teacher_10102023_ver2
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/det_cml_train_teacher_10102023_ver2/runs/dgmxuy8k
# [2023/10/10 06:18:04] ppocr INFO: Architecture :
# [2023/10/10 06:18:04] ppocr INFO:     Models :
# [2023/10/10 06:18:04] ppocr INFO:         Student :
# [2023/10/10 06:18:04] ppocr INFO:             Backbone :
# [2023/10/10 06:18:04] ppocr INFO:                 in_channels : 3
# [2023/10/10 06:18:04] ppocr INFO:                 layers : 50
# [2023/10/10 06:18:04] ppocr INFO:                 name : ResNet
# ...

# %% [markdown]
# ####Evaluate trên tập test

# %%
# !python3 tools/eval.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PP-OCR3_det_student_1.yml  -o Global.checkpoints="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/best_accuracy.pdparams" PostProcess.box_thresh=0.6 PostProcess.unclip_ratio=1.5
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/detection_PPOCR3student_1/wandb/run-20231010_182532-ruiv2jld
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run polar-night-10
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1/runs/ruiv2jld
# [2023/10/10 18:25:33] ppocr INFO: Architecture :
# [2023/10/10 18:25:33] ppocr INFO:     Backbone :
# [2023/10/10 18:25:33] ppocr INFO:         disable_se : True
# [2023/10/10 18:25:33] ppocr INFO:         model_name : large
# [2023/10/10 18:25:33] ppocr INFO:         name : MobileNetV3
# [2023/10/10 18:25:33] ppocr INFO:         scale : 0.5
# [2023/10/10 18:25:33] ppocr INFO:     Head :
# [2023/10/10 18:25:33] ppocr INFO:         k : 50
# ...

# %% [markdown]
# ####Infer mô hình detect

# %%
# !python3 tools/infer_det.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PP-OCR3_det_student_1.yml -o Global.infer_img="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data/Detection/data1/images" Global.pretrained_model="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/best_accuracy.pdparams"
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/detection_PPOCR3student_1/wandb/run-20231010_182840-98ote1fn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run soft-disco-11
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/det_ppocrv3_student_10102023_ver1/runs/98ote1fn
# [2023/10/10 18:28:41] ppocr INFO: Architecture :
# [2023/10/10 18:28:41] ppocr INFO:     Backbone :
# [2023/10/10 18:28:41] ppocr INFO:         disable_se : True
# [2023/10/10 18:28:41] ppocr INFO:         model_name : large
# [2023/10/10 18:28:41] ppocr INFO:         name : MobileNetV3
# [2023/10/10 18:28:41] ppocr INFO:         scale : 0.5
# [2023/10/10 18:28:41] ppocr INFO:     Head :
# [2023/10/10 18:28:41] ppocr INFO:         k : 50
# ...

# %%
# !python3 tools/export_model.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PP-OCR3_det_student_1.yml -o Global.pretrained_model="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/best_accuracy.pdparams" Global.save_inference_dir="./output/det_db_inference/det_10102023_ver1/"
# Out:
# W1010 18:34:50.984774 24425 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.0, Runtime API Version: 11.8
# W1010 18:34:50.985926 24425 gpu_resources.cc:149] device: 0, cuDNN Version: 8.9.
# [2023/10/10 18:34:52] ppocr INFO: load pretrain successful from /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/detection_PPOCR3student_1/best_accuracy
# I1010 18:34:58.779239 24425 interpretercore.cc:237] New Executor is Running.
# [2023/10/10 18:34:59] ppocr INFO: inference model is saved to ./output/det_db_inference/det_10102023_ver1/inference

# %%
# !python3 tools/infer/predict_det.py --det_algorithm="DB" --det_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/det_db_inference/det_10102023_ver1" --image_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data/Detection/data1/images" --use_gpu=True
# Out:
# [2023/10/10 18:36:09] ppocr INFO: 20221022_000000.jpg	[[[292.0, 915.0], [430.0, 915.0], [430.0, 925.0], [292.0, 925.0]], [[311.0, 902.0], [409.0, 902.0], [409.0, 912.0], [311.0, 912.0]], [[183.0, 889.0], [535.0, 889.0], [535.0, 899.0], [183.0, 899.0]], [[163.0, 800.0], [222.0, 800.0], [222.0, 811.0], [163.0, 811.0]], [[164.0, 785.0], [624.0, 785.0], [624.0, 799.0], [164.0, 799.0]], [[631.0, 781.0], [653.0, 781.0], [653.0, 877.0], [631.0, 877.0]], [[164.0, 773.0], [622.0, 773.0], [622.0, 783.0], [164.0, 783.0]], [[635.0, 773.0], [650.0, 773.0], [650.0, 786.0], [635.0, 786.0]], [[165.0, 760.0], [623.0, 760.0], [623.0, 771.0], [165.0, 771.0]], [[164.0, 745.0], [623.0, 746.0], [623.0, 759.0], [164.0, 758.0]], [[165.0, 732.0], [623.0, 733.0], [623.0, 745.0], [165.0, 744.0]], [[164.0, 719.0], [624.0, 719.0], [624.0, 732.0], [164.0, 732.0]], [[165.0, 705.0], [621.0, 705.0], [621.0, 716.0], [165.0, 716.0]], [[163.0, 690.0], [624.0, 691.0], [624.0, 704.0], [163.0, 703.0]], [[101.0, 691.0], [1
# ...

# %% [markdown]
# ###Text Recognition

# %% [markdown]
# ####Prepare pretrained params

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/
# !tar xf en_PP-OCRv3_rec_train.tar
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PaddleOCR
# Out:
# /content/drive/MyDrive/ColabNotebooks/PaddleOCR

# %% [markdown]
# ####Train model text recognition SVTR algorithms

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/config.yml \
         -o Global.pretrained_model=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/en_PP-OCRv3_rec_train/best_accuracy.pdparams

# %% [markdown]
# ####Evaluate text recognition trên tập test

# %%
# GPU evaluation, Global.checkpoints is the weight to be tested
# !python3 tools/eval.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/config.yml -o Global.checkpoints=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/best_accuracy.pdparams
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/v3_en_mobile_06102023_v1/wandb/run-20231010_204004-thyy3lms
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run brisk-water-12
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/rec_05102023_toi_0610v1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/rec_05102023_toi_0610v1/runs/thyy3lms
# [2023/10/10 20:40:05] ppocr INFO: Architecture :
# [2023/10/10 20:40:05] ppocr INFO:     Backbone :
# [2023/10/10 20:40:05] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/10/10 20:40:05] ppocr INFO:         last_pool_kernel_size : [2, 2]
# [2023/10/10 20:40:05] ppocr INFO:         last_pool_type : avg
# [2023/10/10 20:40:05] ppocr INFO:         name : MobileNetV1Enhance
# [2023/10/10 20:40:05] ppocr INFO:         scale : 0.5
# [2023/10/10 20:40:05] ppocr INFO:     Head :
# ...

# %%
# Predict English results
# !python3 tools/infer_rec.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/config.yml -o Global.pretrained_model=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/best_accuracy.pdparams  Global.infer_img=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/v3_en_mobile_06102023_v1/wandb/run-20231011_023035-hwrikll8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-terrain-13
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/rec_05102023_toi_0610v1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/rec_05102023_toi_0610v1/runs/hwrikll8
# [2023/10/11 02:30:44] ppocr INFO: Architecture :
# [2023/10/11 02:30:44] ppocr INFO:     Backbone :
# [2023/10/11 02:30:44] ppocr INFO:         last_conv_stride : [1, 2]
# [2023/10/11 02:30:44] ppocr INFO:         last_pool_kernel_size : [2, 2]
# [2023/10/11 02:30:44] ppocr INFO:         last_pool_type : avg
# [2023/10/11 02:30:44] ppocr INFO:         name : MobileNetV1Enhance
# [2023/10/11 02:30:44] ppocr INFO:         scale : 0.5
# [2023/10/11 02:30:44] ppocr INFO:     Head :
# ...

# %%
# -c Set the training algorithm yml configuration file
# -o Set optional parameters
# Global.pretrained_model parameter Set the training model address to be converted without adding the file suffix .pdmodel, .pdopt or .pdparams.
# Global.save_inference_dir Set the address where the converted model will be saved.

# !python3 tools/export_model.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/config.yml -o Global.pretrained_model=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/best_accuracy.pdparams  Global.save_inference_dir=./inference/en_rec_ppocrv3_11102023_ver1/
# Out:
# W1011 02:37:33.690783  8744 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.0, Runtime API Version: 11.8
# W1011 02:37:33.691851  8744 gpu_resources.cc:149] device: 0, cuDNN Version: 8.9.
# [2023/10/11 02:37:35] ppocr INFO: load pretrain successful from /content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/v3_en_mobile_06102023_v1/best_accuracy
# I1011 02:37:41.521868  8744 interpretercore.cc:237] New Executor is Running.
# [2023/10/11 02:37:41] ppocr INFO: inference model is saved to ./inference/en_rec_ppocrv3_11102023_ver1/inference

# %%
# !python3 tools/infer/predict_rec.py --image_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images" \
--rec_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/inference/en_rec_ppocrv3_11102023_ver1" \
--rec_char_dict_path="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/ppocr/utils/en_dict.txt"
# Out:
# [2023/10/11 02:39:59] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2023/10/11 02:40:06] ppocr INFO: Predicts of /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images/20230420_000001.jpg:('Tiredness', 0.9996060132980347)
# [2023/10/11 02:40:06] ppocr INFO: Predicts of /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images/20230420_000002.jpg:('kills', 0.9935391545295715)
# [2023/10/11 02:40:06] ppocr INFO: Predicts of /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images/20230420_000003.jpg:('A', 0.997394323348999)
# [2023/10/11 02:40:06] ppocr INFO: Predicts of /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/data2/images/20230420_000004.jpg:('short', 0.9838162660598755)
# ...

# %% [markdown]
# ####Infer trên cả model detect và recognition

# %%
# !python3 tools/infer/predict_system.py --rec_char_dict_path="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/ppocr/utils/en_dict.txt" \
--image_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data/Detection/data1/images/20221022_000000.jpg" \
--det_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/det_db_inference/det_10102023_ver1/" \
--rec_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/inference/en_rec_ppocrv3_11102023_ver1" \
--use_angle_cls=false \
--draw_img_save_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/inference_both/"
# Out:
# [2023/10/11 02:48:33] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2023/10/11 02:48:35] ppocr DEBUG: dt_boxes num : 38, elapsed : 1.4509549140930176
# [2023/10/11 02:48:35] ppocr DEBUG: rec_res num  : 38, elapsed : 0.23827052116394043
# [2023/10/11 02:48:35] ppocr DEBUG: 0  Predict time of /content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data/Detection/data1/images/20221022_000000.jpg: 1.696s
# [2023/10/11 02:48:35] ppocr DEBUG: ATT.GEN.ADMIN.OFFICE FaX:614-466-SO87, 0.882
# [2023/10/11 02:48:35] ppocr DEBUG: Dec 1098, 0.952
# [2023/10/11 02:48:35] ppocr DEBUG: 17:46, 0.970
# [2023/10/11 02:48:35] ppocr DEBUG: P.01, 0.968
# [2023/10/11 02:48:35] ppocr DEBUG: Attornev General, 0.987
# [2023/10/11 02:48:35] ppocr DEBUG: Betty D.Montgomery, 0.970
# [2023/10/11 02:48:35] ppocr DEBUG: CONFIDENTIAY.FACSIMLE, 0.808
# ...

# %%
# !python3 tools/infer/predict_system.py --rec_char_dict_path="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/ppocr/utils/en_dict.txt" \
--image_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/dataset/test/evaluate_data/Detection/data1/images/20221022_000000.jpg" \
--det_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/det_db_inference/det_10102023_ver1/" \
--rec_model_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/inference/en_rec_ppocrv3_11102023_ver1" \
--use_angle_cls=false \
--draw_img_save_dir="/content/drive/MyDrive/ColabNotebooks/PaddleOCR/output/inference_both/"

# %% [markdown]
# ####Resnet50 (draft)

# %%
# !python3 tools/train.py -c /content/drive/MyDrive/ColabNotebooks/PaddleOCR/configuration/ch_PPOCR3_det_dml.yml \
    -o Architecture.Models.Student.pretrained=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/best_accuracy_res50_12e.pdparams \
       Architecture.Models.Student2.pretrained=/content/drive/MyDrive/ColabNotebooks/PaddleOCR/pretrained_model/ch_PP-OCRv3_det_distill_train/teacher_10102023.pdparams \
       Global.save_model_dir=./output/det_ppocrv3_det_12102023_ver1
# Out:
# wandb: Currently logged in as: hoangquan121202 (qaihanoi). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.12
# wandb: Run data is saved locally in ./output/det_ppocrv3_det_12102023_ver1/wandb/run-20231012_021400-z0ntyy90
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-jazz-4
# wandb: ⭐️ View project at https://wandb.ai/qaihanoi/det_db_ppocrv3_12102023_ver1
# wandb: 🚀 View run at https://wandb.ai/qaihanoi/det_db_ppocrv3_12102023_ver1/runs/z0ntyy90
# [2023/10/12 02:14:11] ppocr INFO: Architecture :
# [2023/10/12 02:14:12] ppocr INFO:     Models :
# [2023/10/12 02:14:12] ppocr INFO:         Student :
# [2023/10/12 02:14:12] ppocr INFO:             Backbone :
# [2023/10/12 02:14:12] ppocr INFO:                 in_channels : 3
# [2023/10/12 02:14:12] ppocr INFO:                 layers : 50
# [2023/10/12 02:14:12] ppocr INFO:                 name : ResNet
# [2023/10/12 02:14:12] ppocr INFO:             Head :
# ...

# %%
# !wget -P ./pretrain_models/ https://paddleocr.bj.bcebos.com/pretrained/ResNet50_vd_ssld_pretrained.pdparams
# Out:
# --2023-10-12 02:11:05--  https://paddleocr.bj.bcebos.com/pretrained/ResNet50_vd_ssld_pretrained.pdparams
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 124.237.208.76, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|124.237.208.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94351238 (90M) [application/octet-stream]
# Saving to: ‘./pretrain_models/ResNet50_vd_ssld_pretrained.pdparams’
#
# ResNet50_vd_ssld_pr 100%[===================>]  89.98M  16.1MB/s    in 17s
#
# 2023-10-12 02:11:23 (5.26 MB/s) - ‘./pretrain_models/ResNet50_vd_ssld_pretrained.pdparams’ saved [94351238/94351238]
